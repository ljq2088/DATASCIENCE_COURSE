# %%
import sys
import os
import math
from math import pi
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from scipy.fftpack import fft, ifft
from mpl_toolkits.mplot3d import Axes3D
from scipy.signal import firwin2,welch

# %%
import numpy as np

data = np.loadtxt('iLIGOSensitivity.txt', delimiter='\t')  # 如果数据是空格分隔的
plt.loglog(data[:,0],data[:,1],'r',label="LIGO Sensitivity")
plt.grid(True)
plt.xlabel("f/Hz")
plt.ylabel("Sensitivity/Hz^-1/2")
plt.legend(loc='upper left')
plt.title("LIGO Sensitivity")
plt.show()
